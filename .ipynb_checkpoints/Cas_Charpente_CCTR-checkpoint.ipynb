# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["figure.figsize"] = (8,6)
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import numpy as np
from numpy.linalg import inv

### Etape 1 : on defini notre geometrie
#%run src\Cas_Test.ipynb
# %run src\Fonctions.ipynb

nb_noeud = 10

E = 12e9 # Module D'Young [en Pa]
rho = 7800 
L = 3.55 # Longueur de la poutre [en m]
h = 0.55 # hauteur [en m]
b = 0.35 #largueur [en m]
S = b*h # Section [en m^2]
I = b*h**3/12 # Inertie [en m]
q = 2000 # Charge repartie (en N/m)
scale = 1e3

def K_elem(L_e) :
    K_elem = E*I/L_e**3*np.array([[12, 6*L , -12, 6*L],
                            [6*L, 4*L**2 , -6*L, 2*L**2],
                            [-12, -6*L, 12, -6*L],
                            [6*L, 2*L**2 , -6*L , 4*L**2]])
    return K_elem

print("====> poutre encastree aux extremites")
U,NL,EL, f_max, M_max,sig_max = solve_flexion(nb_noeud,bc = 1)
plot_disp_flexion(NL,U,scale)
plot_disp_f(NL,U)

print("\n ===> poutre en rotation aux extremites")
U,NL,EL, f_max, M_max,sig_max = solve_flexion(nb_noeud,bc = 2)
plot_disp_flexion(NL,U,scale)
plot_disp_f(NL,U)
# Out:
# ====> poutre encastree aux extremites
# Nombre de noeuds : 10
# Nombre de elements : 9
# Fleche maximum =  0.00012471207819641638  [en m]
# Moment maximum =  170133.75000000017  [en N.m]
# Contrainte maximum =  9.641582054309337  [en MPa]
#
#  ===> poutre en rotation aux extremites
# Nombre de noeuds : 10
# Nombre de elements : 9
# Fleche maximum =  0.000629795994891913  [en m]
# Moment maximum =  1.862645149230957e-09  [en N.m]
# Contrainte maximum =  1.055572221524037e-13  [en MPa]

# %%
def convergence_fleche(nb_max):
    Nb = []
    F = []
    M = []
    S= []
    for i in range(2,nb_max,10) : 
        U,NL,EL, f_max, M_max,sig_max = solve_flexion(i,bc=1)
        Nb.append(i)
        F.append(f_max)
        M.append(M_max)
        S.append(sig_max)
    plt.plot(Nb,F,label="fleche")
    plt.plot(Nb,M,label="moment")
    plt.plot(Nb,S,label="contraint")
    plt.legend()
    plt.xlabel("nombre de noeuds")
    plt.grid()
    return

convergence_fleche(nb_max=250)
# Out:
# Nombre de noeuds : 2
# Nombre de elements : 1
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : 0.0
# Fleche maximum =  0.0  [en m]
# Moment maximum =  2100.4166666666665  [en N.m]
# Contrainte maximum =  0.11903187721369538  [en MPa]
# Nombre de noeuds : 12
# Nombre de elements : 11
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -8.415752338229864e+219
# Fleche maximum =  0.00015368819403580765  [en m]
# Moment maximum =  254150.41666665536  [en N.m]
# Contrainte maximum =  14.402857142856503  [en MPa]
# Nombre de noeuds : 22
# Nombre de elements : 21
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.00029696381885409935  [en m]
# Moment maximum =  926283.7500003142  [en N.m]
# Contrainte maximum =  52.493057851257475  [en MPa]
# Nombre de noeuds : 32
# Nombre de elements : 31
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.0004394540337944357  [en m]
# Moment maximum =  2018500.4166698067  [en N.m]
# Contrainte maximum =  114.38963400253921  [en MPa]
# Nombre de noeuds : 42
# Nombre de elements : 41
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0005817321470524711  [en m]
# Moment maximum =  3530800.416646356  [en N.m]
# Contrainte maximum =  200.09258559507097  [en MPa]
# Nombre de noeuds : 52
# Nombre de elements : 51
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.0007239227722509462  [en m]
# Moment maximum =  5463183.750019847  [en N.m]
# Contrainte maximum =  309.6019126339465  [en MPa]
# Nombre de noeuds : 62
# Nombre de elements : 61
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.0008660689035469989  [en m]
# Moment maximum =  7815650.416642391  [en N.m]
# Contrainte maximum =  442.9176151107848  [en MPa]
# Nombre de noeuds : 72
# Nombre de elements : 71
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0010081893313227672  [en m]
# Moment maximum =  10588200.416605292  [en N.m]
# Contrainte maximum =  600.0396930307603  [en MPa]
# Nombre de noeuds : 82
# Nombre de elements : 81
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0011502935717043377  [en m]
# Moment maximum =  13780833.749691384  [en N.m]
# Contrainte maximum =  780.9681463815659  [en MPa]
# Nombre de noeuds : 92
# Nombre de elements : 91
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0012923869595146639  [en m]
# Moment maximum =  17393550.415136036  [en N.m]
# Contrainte maximum =  985.7029751198697  [en MPa]
# Nombre de noeuds : 102
# Nombre de elements : 101
#  ### Debut de l'assemblage ###
# D:\DATA\n.gameiro\Anaconda3\lib\site-packages\numpy\linalg\linalg.py:2158: RuntimeWarning: overflow encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0014344727180477424  [en m]
# Moment maximum =  21426350.41870727  [en N.m]
# Contrainte maximum =  1214.2441795725488  [en MPa]
# Nombre de noeuds : 112
# Nombre de elements : 111
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.0015765529084424564  [en m]
# Moment maximum =  25879233.75528301  [en N.m]
# Contrainte maximum =  1466.5917594493321  [en MPa]
# Nombre de noeuds : 122
# Nombre de elements : 121
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.0017186289106310203  [en m]
# Moment maximum =  30752200.418947298  [en N.m]
# Contrainte maximum =  1742.745714414959  [en MPa]
# Nombre de noeuds : 132
# Nombre de elements : 131
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0018607016853709642  [en m]
# Moment maximum =  36045250.43546454  [en N.m]
# Contrainte maximum =  2042.7060459295135  [en MPa]
# Nombre de noeuds : 142
# Nombre de elements : 141
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0020027719159167534  [en m]
# Moment maximum =  41758383.74904356  [en N.m]
# Contrainte maximum =  2366.472750831276  [en MPa]
# Nombre de noeuds : 152
# Nombre de elements : 151
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0021448401090939373  [en m]
# Moment maximum =  47891600.38574154  [en N.m]
# Contrainte maximum =  2714.0458305969228  [en MPa]
# Nombre de noeuds : 162
# Nombre de elements : 161
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.0022869066469428973  [en m]
# Moment maximum =  54444900.39990216  [en N.m]
# Contrainte maximum =  3085.425288306143  [en MPa]
# Nombre de noeuds : 172
# Nombre de elements : 171
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.002428971819452502  [en m]
# Moment maximum =  61418283.76975768  [en N.m]
# Contrainte maximum =  3480.6111227253464  [en MPa]
# Nombre de noeuds : 182
# Nombre de elements : 181
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0025710358532212403  [en m]
# Moment maximum =  68811750.51530536  [en N.m]
# Contrainte maximum =  3899.6033349877885  [en MPa]
# Nombre de noeuds : 192
# Nombre de elements : 191
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.002713098920160871  [en m]
# Moment maximum =  76625300.4635206  [en N.m]
# Contrainte maximum =  4342.401915288062  [en MPa]
# Nombre de noeuds : 202
# Nombre de elements : 201
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.002855161177261877  [en m]
# Moment maximum =  84858933.9831037  [en N.m]
# Contrainte maximum =  4809.006884520634  [en MPa]
# Nombre de noeuds : 212
# Nombre de elements : 211
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.0029972227173308457  [en m]
# Moment maximum =  93512650.3308449  [en N.m]
# Contrainte maximum =  5299.418200567361  [en MPa]
# Nombre de noeuds : 222
# Nombre de elements : 221
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.003139283677747859  [en m]
# Moment maximum =  102586450.8298818  [en N.m]
# Contrainte maximum =  5813.6359384112475  [en MPa]
# Nombre de noeuds : 232
# Nombre de elements : 231
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : -inf
# Fleche maximum =  0.0032813440810067493  [en m]
# Moment maximum =  112080333.76305713  [en N.m]
# Contrainte maximum =  6351.660000739955  [en MPa]
# Nombre de noeuds : 242
# Nombre de elements : 241
#  ### Debut de l'assemblage ###
# ### Fin de l'assemblage ###
# determinant : inf
# Fleche maximum =  0.003423404072181777  [en m]
# Moment maximum =  121994301.59533833  [en N.m]
# Contrainte maximum =  6913.490527244675  [en MPa]

# %% [markdown]
# ### Résultats analytiques
#
# On peut utiliser la résistance des matériaux pour modéliser une poutre en flexion encastrée à ses deux extremités.
#
# On obtient une fléche théorique de :
# $$ f_{max} = \frac{qL^4}{76.8EI} $$
#
# Et un moment flechissant maxi mum théorique de :
# $$ M_{max} = \frac{ql^2}{8} $$

# %%
print("f_max = ", q*L**4/76.8/E/I," m")
print("M_max = ", q*L**2/8, " N.m")
# Out:
# f_max =  7.102742578530283e-05  m
# M_max =  3150.625  N.m
